# %% [markdown]
# <h1> Комментарий тимлида </h1>
#
# 👋 **Привет, Каламкас!**
#
# ✨ Поздравляю с началом работы над финальным проектом!
#
# Меня зовут Арсен Абдулин и я буду твоим ревьювером. Предлагаю общаться на «ты», если не против =)
#
# При проверке работ я делаю следующие комментарии:
#
# <div class="alert alert-success">
# <b>✔️ Зеленым цветом</b> отмечены удачные решения.</div>
#
# <div class="alert alert-warning">
# <b>⚠️ Желтым цветом</b> я отметил пункты, которые в следующий раз можно сделать по-другому. Одно-два таких замечания в проекте допускается, но если их много — проект следует доработать. </div>
#
# <div class="alert alert-danger">
# <b>🚫 Красным цветом</b> отмечены критические замечания, которые необходимо поправить, чтобы принять проект. </div>
#
# Если какие-то моменты в задании для тебя были непонятны и у тебя есть ко мне вопросы — смело спрашивай 😊 Также ты можешь доработать места, где есть желтые комментарии в проекте (однако, это не обязательно).
#
# Предлагаю работать в диалоге: если ты решишь что-то поменять по моим рекомендациям — пиши об этом (выбери для своих комментариев определенный цвет - так мне будет легче увидеть изменения). Пожалуйста не перемещай, не изменяй и не удаляй мои комментарии. Все это поможет сделать проверку твоего проекта оперативнее.
#
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Пример комментария. </div>

# %% [markdown]
# <b>Проект Телекоммуникации:</b>
#
# Задача: Спронозировать отток клиентов для целей их удержания с помощью промо и специальных условий.
# Наш клиент - оператор связи, предоставляющий два основных вида услуг: 1) Стационарная телефонная связь 2) Интернет услуги. Также предоставляются доп услуги по типу антивируса и пр.
#
# Данные - 4 файла с данными по контрактам, персональной инфо клиентов, инфо об интернет услугах а также услугах телефонии.
# Данные актуальны по состоянию на 01/02/20.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Хорошо, когда есть небольшое описание проекта — так постороннему человеку будет проще ознакомиться!
#
# Желательно также добавить цель работы
#
# </div>

# %% [markdown]
# <b>План действий:<b> <br>
# 1) Подготовка и обработка данных <br>
# 2) EDA <br>
# 3) Обучение нескольних моделей на трейне и выбор лучшей модели с тз метрики качества (ROC-AUC + Accuracy) <br>
# 4) Проверка избранной модели на тесте <br>
# 5) Анализ результатов и выводы. <br>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> Напиши пожалуйста основные пункты плана работ в отдельной строке каждый.
#
# </div>

# %% [markdown]
# Подробнее о каждом из шагов:
# 1. Объединить 4 файла в 1. Обработать пропуски и сгенерировать признаки. <br>
# 2. Изучить данные - размер датасета, типов данных, ОС, распределение значений признаков, обработка аномальных значений, проверка на корреляцию между признаками, определиться с набором признаков для дальнейшего моделирования. Также необходимо привести данные к одному масштабу методом Standart Scaler, сбалансировать классы (с помощью параметра внутри модели), а также закодировать категориальные переменные методом OHE. Для оптимизации этих процессов попробую использовать пайплайн. <br>
# 3. На трейне планирую использовать модели: СЛ, градиентный бустинг и возможно лог регрессию. Подбор параметров планирую осуществить с помощью gridsearch, обучение будет проходит с помощью кросс валидации. <br>
# 4. Размер тестовой выборки составит 25% от исходной. Тест лучшей модели и расчет метрик качества. <br>
# 5. Анализ результатов и выводы. <br>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> В целом по плану работ все хорошо, необходимые этапы на месте!
# </div>

# %%
import pandas as pd
from pyspark.sql import SparkSession
import matplotlib.pyplot as plt
import seaborn as sns
import phik
from phik.report import plot_correlation_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
import lightgbm
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
import time
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_31/18921599.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import phik
#       6 from phik.report import plot_correlation_matrix
#       7 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'phik'

# %% [markdown]
# Объединим данные в 1 таблицу.

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий тимлида:</b> Необходимо добавить обработку исключений при загрузке файлов, например с помощью try/except
#
# Необходимо, чтобы файлы также загружались с сервера Яндекс:
#
#     '/datasets/contract_new.csv'
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Поправила. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хорошо!
#
# </div>

# %%
APP_NAME = 'DataFrames'
SPARK_URL = 'local[*]'

spark = SparkSession.builder.appName(APP_NAME).getOrCreate() 

try:
    contract_new = spark.read.load('/Users/kalamkas/Downloads/contract_new.csv', format='csv', header='true', inferSchema='true')
except:
    contract_new = spark.read.load('/datasets/contract_new.csv', format='csv', header='true', inferSchema='true')

try:
    personal_new = spark.read.load('/Users/kalamkas/Downloads/personal_new.csv', format='csv', header='true', inferSchema='true')
except:
    personal_new = spark.read.load('/datasets/personal_new.csv', format='csv', header='true', inferSchema='true')
    
try:
    internet_new = spark.read.load('/Users/kalamkas/Downloads/internet_new.csv', format='csv', header='true', inferSchema='true')
except:
    internet_new = spark.read.load('/datasets/internet_new.csv', format='csv', header='true', inferSchema='true')

try:
    phone_new = spark.read.load('/Users/kalamkas/Downloads/phone_new.csv', format='csv', header='true', inferSchema='true')
except:
    phone_new = spark.read.load('/datasets/phone_new.csv', format='csv', header='true', inferSchema='true')

#contract_new.show(5)

# %%
contract_new.registerTempTable('contract_new')
personal_new.registerTempTable('personal_new')
internet_new.registerTempTable('internet_new')
phone_new.registerTempTable('phone_new')

#print(spark.sql('select * from contract_new').show())

# %%
data = spark.sql("SELECT c.*, gender, SeniorCitizen, Partner, Dependents, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, MultipleLines FROM contract_new c LEFT JOIN personal_new p ON c.customerId = p.customerId LEFT JOIN internet_new i ON c.customerId = i.customerId LEFT JOIN phone_new ph ON c.customerId = ph.customerId")

# %%
data.registerTempTable("data")

# %%
pd.set_option('display.max_columns', None)
data = data.toPandas()
data.head()

# %%
data.info()

# %% [markdown]
# Нашим целевым признаком будет преобразованное поле EndDate.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Отлично, так мы получим целевую переменную!
#
# </div>

# %%
data['Outflow'] = data['EndDate'].apply(lambda x: 1 if x != 'No' else 0)

# %%
#data.loc[data['EndDate'] != 'No'][['EndDate', 'Outflow']]

# %% [markdown]
# Теперь посчитаем длительность пользования клиента услугами оператора. Если клиент все еще активен, то посчитаем кол-во дней и месяцев с начала контракта до даты выгрузки данных.

# %%
def replace(row):
    if row['EndDate'] == 'No':
        return '2020-02-01'
    else:
        return row['EndDate']
    

data['EndDateNew'] = data.apply(replace, axis=1)

# %%
data['BeginDate'] = pd.to_datetime(data['BeginDate'], format='%Y-%m-%d')
data['EndDateNew'] = pd.to_datetime(data['EndDateNew'], format='%Y-%m-%d')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Хорошо, так мы получим новый полезный признак для обучения!
#
# </div>

# %%
data['ActiveDays'] = (data['EndDateNew'] - data['BeginDate']).dt.days

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> В целом нет необходимости в признаке ActiveMonths. Но его можно также посчитать аналогично признаку ActiveDays, так будет точнее
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исключу этот признак. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хорошо
#
# </div>

# %%
#data['ActiveMonths'] = round((data['EndDateNew'] - data['BeginDate']).dt.days / 30, 2)

# %% [markdown]
# Заполним пропуски в полях из таблицы 'internet_new' на строковое значение 'not applicable' - для пользователей, не подключивших интернет-услуги. А пустые значения в поле MultipleLines - на 'not defined'.

# %%
columns = ['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

for i in columns:
    data[i] = data[i].fillna('No')

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> Как рекомендация, пропуски в признаках интернета можно заменить значениями No
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Поправила.  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Отлично, так мы избежим появления дополнительных категорий!
#
# </div>

# %%
data['MultipleLines'] = data['MultipleLines'].fillna('not defined')

# %% [markdown]
# Создадим копию датасета и удалим из нее ненужные поля.

# %%
data_new = data.copy()
data_new = data_new.drop(columns=['BeginDate', 'EndDate'], axis=1)
data_new.head()

# %% [markdown]
# Теперь наш датасет готов к дальнейше работе.
# На текущем этапе пока вопросов по проекту не возникло.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> На следующем этапе нужно будет обязательно добавить пути к файлам на сервере Яндекс.
#
# ***
#
# Я принимаю план работ, можно приступать к основному проекту.
#
# Сохрани пожалуйста наши с тобой комментарии, а проект продолжай в этом же файле. Успехов!
# </div>

# %% [markdown]
# <h1> Комментарий ревьювера </h1>
#
# <div class="alert alert-success">
#
# 👋 Каламкас, привет еще раз! Это снова Арсен Абдулин — и я буду делать ревью основного проекта.
#
# Давай посмотрим, что получилось.
#
# </div>

# %% [markdown]
# <b>Перейдем к этапу EDA:</b>

# %% [markdown]
# Получившийся датасет состоит из 7034 строк и 21 поля. Нужно поменять тип данных в поле TotalCharges на float, но сначала удалим из датасета строки со значениями ' ' в этом поле - их всего 11.

# %%
data_new.shape

# %%
data_new.info()

# %%
list = []
for i in data_new['TotalCharges'].unique():
    try:
        float(i)
    except:
        list.append(i)

# %%
list

# %%
data_new[data_new['TotalCharges'] == ' ']['TotalCharges'].count()

# %%
data_new = data_new[data_new['TotalCharges'] != ' ']

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Как рекомендация, можно проверить, с чем связаны пропуски в признаке TotalCharges
#
# </div>

# %%
data_new['TotalCharges'] = data_new['TotalCharges'].apply(lambda x: float(x))

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Можно поменять тип данных через astype()
#
# </div>

# %%
data_new.describe()

# %% [markdown]
# Посмотрим на распределения количественных признаков:

# %%
columns = ['MonthlyCharges', 'TotalCharges', 'ActiveDays']

for i in columns:
    data_new[i].plot(kind='hist', bins=50, title=i)
    plt.show()

# %%
for i in columns:
    sns.boxplot(data=data_new, y=i)
    plt.show()

# %% [markdown]
# Как видно из гистрограмм и графиков ящик с усами данные распределены неравномерно. MonthlyCharges - смещены влево, средняя < медианы. Виден явный пик в диапазоне 20-25. TotalCharges наоборот скошен вправо, также присутсвуют аномальные значения > 7500 - 195 шт - их мы удалим.

# %%
#data_new[columns].boxplot()

# %%
#threshold = data_new['TotalCharges'].quantile(0.75) + (data_new['TotalCharges'].quantile(0.75) - data_new['TotalCharges'].quantile(0.25)) * 1.5

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий тимлида:</b> Хотя в признаке TotalCharges есть выбросы, судя по диаграмме размаха, но в целом данные выглядят адекватно, просто у клиентов высокие платежи. Мы должны также предсказывать лояльность этих клиентов, поэтому данные нужно сохранить
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Поняла, удалять не буду.  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо 👍
#
# </div>

# %%
#data_new[data_new['TotalCharges'] > threshold]['TotalCharges'].count()

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> В нашем проекте необходимо сравнить распределения для групп ушедших и оставшихся клиентов. Например, как отличаются ежемесячные платежи, количество дней контракта и др.
#
# Удобно применить метод histplot:
#
#     sns.histplot(data, x=column, hue='target', multiple='stack')
#
# https://seaborn.pydata.org/generated/seaborn.histplot.html
#
# Необходимо также добавить небольшие аналитические выводы
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Добавили ниже.  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Отличная работа!
#
# </div>

# %% [markdown]
# Сравним распределения TotalCharges и ActiveDays для активных и ушедших клиентов.

# %%
sns.histplot(data=data_new, x='TotalCharges', multiple='stack', hue='Outflow')

# %%
sns.histplot(data=data_new, x='ActiveDays', multiple='stack', hue='Outflow')

# %% [markdown]
# <b>Выводы:</b> Как видно из графиков, у активных клиентов суммарные расходы чаще всего сосредоточены в диапазоне <300, далее наблюдается резкий спад. Ушедшие клиенты более равномерно распределились по уровням расходов, при этом пик у них приходится на отрезок 800-900к. Дальше также заметно снижение, но более плавное.
# Распределение кол-ва активных дней у ушедших клиентов - очень близко к нормальному, у активных - видны два пика в самом начале и в самом конце. Первый пик можно объяснить тем, что пришло очень много новичков, которые еще не успели поуходить. Второй пик говорит о том, что после отметки 2000 дней клиенты менее склонны к уходу, может быть изза сформировавшихся привычек или лояльности к оператору.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Здорово, что сравнила ушедших и оставшихся клиентов по ежемесячным платежам =)
#
# ***
#
# Еще нужно только помнить, что влияние различных факторов на целевую переменную, это гипотеза, и нужно использовать методы проверки гипотез. Но это уже отдельная работа =)
#
# </div>

# %% [markdown]
# Теперь необходимо проверить наличие корреляции между признаками. Используем для этого коэф $\phi_K$. Но сначала удалим поле EndDateNew за ненадобностью.

# %%
data_new = data_new.drop(columns='EndDateNew', axis=1)
df = data_new.set_index(['customerID'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/2155641633.py in <module>
# ----> 1 data_new = data_new.drop(columns='EndDateNew', axis=1)
#       2 df = data_new.set_index(['customerID'])
#
# NameError: name 'data_new' is not defined

# %%
phik_overview = df.phik_matrix(interval_cols=['MonthlyCharges', 'TotalCharges', 'ActiveDays'])
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map='Greens',
                        title=r'correlation $\phi_K$',
                        fontsize_factor=1.0,
                        figsize=(10, 8))
plt.tight_layout()

# %% [markdown]
# На матрице выше наблюдаем корреляцию между след признаками: <br>
# ActiveDays TotalCharges <b>0.85</b> <br>
# ActiveDays Type 0.64 <br>
# MultipleLines MonthlyCharges 0.71 <br>
# MultipleLines InternetService 0.74 <br>
# StreamingMovies StreamingTV 0.74 <br>
# StreamingMovies TotalCharges 0.64 <br>
# StreamingMovies MonthlyCharges 0.83 <br>
# StreamingTV TotalCharges 0.64 <br>
# StreamingTV MonthlyCharges 0.84 <br>
# DeviceProtection TotalCharges 0.64 <br>
# DeviceProtection MonthlyCharges 0.67 <br>
# OnlineBackup TotalCharges 0.62 <br>
# OnlineBackup MonthlyCharges 0.63 <br>
# InternetService MonthlyCharges <b>0.92</b> <br>
# Dependencies Partner 0.65 <br>
# TotalCharges MonthlyCharges 0.71 <br>
#
# Проверим стат значимость этой корреляции.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Здорово, что применила библиотеку phik для анализа корреляции смешанного набора признаков!
#
# ***
#
# Что касается корреляции категориальных признаков, то это пока что пища для размышлений, не стоит сразу по этому условию удалять признаки. Данная корреляция может быть нелинейная, и на линейные модели это не повлияет.
#
# </div>

# %%
significance_overview = df.significance_matrix(interval_cols=['MonthlyCharges', 'TotalCharges', 'ActiveDays'])
plot_correlation_matrix(significance_overview.fillna(0).values,
                        x_labels=significance_overview.columns,
                        y_labels=significance_overview.index,
                        vmin=-5, vmax=5, #color_map='Greens',
                        title='Significance of the coefficients',
                        usetex=False,
                        fontsize_factor=1.0,
                        figsize=(14, 10))
plt.tight_layout()

# %% [markdown]
# Как видно из матрицы значимости коэффициентов, почти между всеми признаками значение коэф-та корреляции статистически значимый. Очевидно, что удалить все признакми между которыми наблюдается высокая корреляция мы не можем - удалим только MonthlyCharges (тк у нас уже есть признак отвечающий за объем расходов TotalCharges) и StreamingMovies, который по сути может заменить StreamingTV.

# %%
data_new = data_new.drop(columns=['MonthlyCharges', 'StreamingMovies'], axis=1)

# %% [markdown]
# <b>Теперь перейдем к этапу масшатирования и кодирования данных и обучения моделей с помощью пайплайнов. Но для начала разобьем датасет на обучающую и тестовую выборки. </b>

# %%
features = data_new.drop(columns=['customerID', 'Outflow'], axis=1)
target = data_new['Outflow']
RANDOM_STATE = 310723

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.25, random_state=RANDOM_STATE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/1005828830.py in <module>
# ----> 1 features = data_new.drop(columns=['customerID', 'Outflow'], axis=1)
#       2 target = data_new['Outflow']
#       3 RANDOM_STATE = 310723
#       4
#       5 X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.25, random_state=RANDOM_STATE)
#
# NameError: name 'data_new' is not defined

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Нужно поправить параметр RANDOM_STATE, это дата начала финального спринта:
#
#     310723
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Поправила.  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> 👍
#
# </div>

# %%
#кат признаки для OHE:
ohe_features = X_train.select_dtypes(include='object').columns.to_list()
ohe_features

# %%
num_features = X_train.select_dtypes(exclude='object').columns.to_list()
num_features.remove('SeniorCitizen')
num_features

# %%
#encoder_ohe = OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False)
#encoder_ohe.fit(X_train[ohe_features])
#X_train[encoder_ohe.get_feature_names_out()] = encoder_ohe.transform(X_train[ohe_features])
#X_train = X_train.drop(ohe_features, axis=1)

#scaler = StandardScaler()
#X_train[num_features] = scaler.fit_transform(X_train[num_features])
#X_train.head()

# %%
#X_test[encoder_ohe.get_feature_names_out()] = encoder_ohe.transform(X_test[ohe_features])
#X_test = X_test.drop(ohe_features, axis=1)

#X_test[num_features] = scaler.transform(X_test[num_features])
#X_test.head()

# %%
#X_train.shape, X_test.shape

# %%
#(X_train.columns != X_test.columns).sum()

# %% [markdown]
# Попробуем воспроизвести те же шаги с помощью трансформера.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Здорово, что попробовала применить column_transformer!
#
# Кодирование и масштабирование признаков выполнено верно
# </div>

# %%
col_transformer = make_column_transformer(
    (
        OneHotEncoder(drop='first', handle_unknown='ignore'),
        ohe_features
    ),
    (
        StandardScaler(),
        num_features
    ),
    remainder='passthrough',
    verbose_feature_names_out=False
)

#X_train_new = X_train.copy()
X_train = pd.DataFrame(#.sparse.from_spmatrix(
    col_transformer.fit_transform(X_train),
    columns=col_transformer.get_feature_names_out()
)

X_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/2854104088.py in <module>
# ----> 1 col_transformer = make_column_transformer(
#       2     (
#       3         OneHotEncoder(drop='first', handle_unknown='ignore'),
#       4         ohe_features
#       5     ),
#
# NameError: name 'make_column_transformer' is not defined

# %%
#X_test_new = X_test.copy()
X_test = pd.DataFrame(#.sparse.from_spmatrix(
    col_transformer.transform(X_test),
    columns=col_transformer.get_feature_names_out()
)

X_test.head()

# %%
X_train.shape, X_test.shape

# %%
(X_train.columns != X_test.columns).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/4123427392.py in <module>
# ----> 1 (X_train.columns != X_test.columns).sum()
#
# NameError: name 'X_train' is not defined

# %%
X_train.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/829181101.py in <module>
# ----> 1 X_train.columns
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# Теперь подберем гиперпараметры для модели <b>LGBMClassifier</b> с помощью GridSearchCV и обучим ее.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Рекомендую не брать слишком глубокие деревья, обычно ограничиваются глубиной не более 10-15
#
# learning_rate = 1 дает нестабильный результат
#
# n_estimators имеет смысл поварьировать
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Поправила </b> Добавили ниже.  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> 👍
#
# </div>

# %%
start_time = time.time()
model_lgbm_clf = LGBMClassifier(random_state=RANDOM_STATE, class_weight='balanced', n_jobs=-1)
#pipeline_lgbm_clf = make_pipeline(col_transformer, model_lgbm_clf)

param_grid_lgbm = {
    'max_depth': [10, 15], #range(1, 41),
    'n_estimators': range(1000, 3000, 500),
    'learning_rate': [0.1, 0.01, 0.001],
    'num_leaves': range(20, 100, 20)
    
}

gs_lgbm = GridSearchCV(
    model_lgbm_clf,
    #pipeline_lgbm_clf,
    param_grid=param_grid_lgbm,
    cv=5,
    scoring='roc_auc'
)

gs_lgbm.fit(X_train, y_train)
print(f'best_score: {gs_lgbm.best_score_}')
print(f'best_params: {gs_lgbm.best_params_}')
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# best_score: 0.8850682885972715
# best_params: {'learning_rate': 0.1, 'max_depth': 15, 'n_estimators': 1000, 'num_leaves': 20}
# --- 997.8511788845062 seconds ---

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Там немного другой синтаксис, например:
#
#     param_grid_lgbm = {
#         'lgbmclassifier__max_depth': [10, 20, 30, 40], #range(1, 41),
#         'lgbmclassifier__n_estimators': range(1000, 3000, 500),
#         'lgbmclassifier__learning_rate': [1, 0.1, 0.01, 0.001],
#         'lgbmclassifier__num_leaves': range(20, 100, 20)
#     }
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b>
# Почему то не удалось использовать пайплайн для этой же задачи - выдает такую ошибку
#
# ```python
# ValueError: Invalid parameter 'max_depth' for estimator Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Type', 'PaperlessBilling',
#                                                    'PaymentMethod', 'gender',
#                                                    'Partner', 'Dependents',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'MultipleLines']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['TotalCharges',
#                                                    'ActiveDays'])],
#                                    verbose_feature_names_out=False)),
#                 ('lgbmclassifier',
#                  LGBMClassifier(class_weight='balanced', random_state=120922))]). Valid parameters are: ['memory', 'steps', 'verbose'].
# ```
#
# </div>

# %% [markdown]
# Сделаем то же самое для модели <b>СЛ</b>.

# %%
start_time = time.time()
model_rf = rf = RandomForestClassifier(random_state=RANDOM_STATE, class_weight='balanced', n_jobs=-1)

param_grid_rf = {
    'max_depth': range(1, 21, 2),
    'n_estimators': [1, 2, 5, 10],
    'min_samples_leaf': [1, 2, 5, 10],
    'min_samples_split': [1, 2, 5, 10]
    
}

gs_rf = GridSearchCV(
    model_rf,
    param_grid=param_grid_rf,
    cv=5,
    scoring='roc_auc'
)

gs_rf.fit(X_train, y_train)
print(f'best_score: {gs_rf.best_score_}')
print(f'best_params: {gs_rf.best_params_}')
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# best_score: 0.8092127579035747
# best_params: {'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 10}
# --- 35.98917508125305 seconds ---

# %% [markdown]
# И для <b>Лог регрессии.</b>

# %%
start_time = time.time()
lr = LogisticRegression(random_state=RANDOM_STATE, max_iter=100, class_weight='balanced')

grid_space = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'penalty': ['l1', 'l2', 'elasticnet'],
    #'C': [5, 10, 15],
    'solver': ['lbfgs', 'liblinear', 'saga', 'newton-cg', 'newton-cholesky', 'sag']
}

gs_lr = GridSearchCV(
    lr,
    param_grid=grid_space,
    cv=5,
    scoring='roc_auc'
)

gs_lr.fit(X_train, y_train)
print(f'best_score: {gs_lr.best_score_}')
print(f'best_params: {gs_lr.best_params_}')
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# best_score: 0.7660268049556612
# best_params: {'C': 1, 'penalty': 'l1', 'solver': 'saga'}
# --- 10.751293897628784 seconds ---
# /Users/kalamkas/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 350 fits failed out of a total of 630.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/kalamkas/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/kalamkas/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
# ...

# %% [markdown]
# Итак, мы обучили 3 модели: LGBMClassifier, модель Случайный лес и Логистической регрессии, среди которых наилучшей с тз метрики качества ROC-AUC оказалась первая. Ее и возьмем на след этап теста.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Здорово, что рассмотрела несколько моделей и сделала перебор гиперпараметров!
#
# Видно, что проделана большая работа 👍
#
# </div>

# %% [markdown]
# <b>Тест</b>

# %%
start_time = time.time()
model_lgbm_clf = LGBMClassifier(
    random_state=RANDOM_STATE,
    class_weight='balanced',
    n_jobs=-1,
    learning_rate=0.1,
    max_depth=15,
    num_leaves=20,
    n_estimators=1000
)

model_lgbm_clf.fit(X_train, y_train)
roc_auc = roc_auc_score(y_test, model_lgbm_clf.predict_proba(X_test)[:, 1])
print(roc_auc)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 0.900059690603704
# --- 0.9726691246032715 seconds ---

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Отличный результат на тестировании, поздравляю!
#
# </div>

# %% [markdown]
# Вот тут хотела уточнить метод .predict_proba() нужно применять к модели (как я сделала выше - в теории курса было как раз так) или к модели + fit() как указано в примере в доке sklearn:
# ``` python
# from sklearn.datasets import load_breast_cancer
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import roc_auc_score
# X, y = load_breast_cancer(return_X_y=True)
# clf = LogisticRegression(solver="liblinear", random_state=0).fit(X, y)
# roc_auc_score(y, clf.predict_proba(X)[:, 1])
# roc_auc_score(y, clf.decision_function(X))
# ```

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Ты все сделала правильно, но чтобы было понятно, нужно разбить на логические части:
#
#     model_lgbm_clf = LGBMClassifier() # объявляем модель
#     model_lgbm_clf.fit(X_train, y_train) # обучаем модель
#     predictions = model_lgbm_clf.predict_proba(X_test)[:, 1] # делаем предсказания
#     roc_auc = roc_auc_score(y_test, predictions) # считаем метрику
#
# Можно еще записать так, но это будет непонятно и неправильно:
#
#     roc_auc = roc_auc_score(y_test, LGBMClassifier().fit(X_train, y_train).predict_proba(X_test)[:, 1])
#
# </div>

# %% [markdown]
# Наша модель на тесте выдала значение ROC_AUC = 90, что соответствует нашему критерию >= 0.85.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Как рекомендация, можно сделать анализ важности признаков для лучшей модели:
#
# Так мы сможем увидеть, какие признаки слабо влияют на отток, и в принципе их можно вообще исключить из обучения, и сделать новую модель, отобрав только самые важные признаки. (Пересчитывать с новыми признаками не нужно).
#
# Анализ важности признаков позволяет не только построить лучшую модель и уменьшить число признаков для обучения. Мы также можем выдать рекомендации бизнесу, изучив влияние признаков на отток, тем самым можно повысить качество определенных услуг, например онлайн-платежи или интернет на оптоволокне.
#
# Желательно добавить график ROC-кривой на тестовой выборке
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Вот небольшие статьи по метрикам в машинном обучении, если заинтересует:
#
# https://habr.com/ru/company/ods/blog/328372/
#
# https://habr.com/ru/company/jetinfosystems/blog/420261/
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Добавь пожалуйста небольшой вывод по работе
#
# </div>

# %% [markdown]
# <b>Выводы: </b>
# Итак, мы загрузили и объединили исходные данные в один датасет. Обработали пропуски и скорректировали типы данных. Добавили доп признаки, удалили ненужные. Привели числовые данные к одному масштабу, закодировали категориальные признаки методом OHE, обучили три модели: градиентного бустинга LGBMClassifier, случайного леса и логистической регрессии. Для каждой модели подобрали значения параметров методом GridSearch. Лучшую модель с тз ROC-AUC - LGBMClassifier взяли на тест. На тесте модель также показала хороший реультат ROC-AUC >= 0,85, из чего можно заключить, что наша модель для целей прогнозирования оттока клиентов подходит.

# %% [markdown]
# Арсен, спасибо за комментарии и рекомендации - мне в работе уверена очень пригодятся. У меня есть пару вопросов, буду признательна если ответишь либо дашь наводку где почитать:
#  - Можно ли получить итоговое уравнение модели? Чтоб условно при необходимости можно было, зная значения признаков, подставить их в уравнение и получить значение таргета? Нам получается нужны значения параметров признаков и сам вид уравнения, для градиентного бустинга видимо это будет не линейное уранвение, а какоето более хитрое.
#  - Когда мы удаляем первый признак при кодировании методом OHE (drop_first=True), я понимаю для чего это делается, и видимо модель удаленный признак все равно учитывает. Но в уравнении же его не будет ? Как это объяснить? Например гендер - M/F , удалим признак M, если F=0, понимаем что клиент мужского пола. Но в уравнении же не будет признака М и соответствующего ему параметра.
#  - Как думаешь, эту дипломную можно использовать для портфолио?
#  - Как я поняла, в МЛ относительно высокий порог входа, и мне как бизнес-аналитику, возможно будет мало одного только курса на Практикуме, может порекомендуешь какие нибудь хорошие платформы / обучалки, которые маст хэв? Или на джуниор позицию можно уже пробоваться - вдруг получится ?)

# %% [markdown]
# <font color=blue>
# <b> ✔️ 👍Заключение ревьювера:</b> Каламкас, было приятно проверять твою работу, она выполнена на хорошем уровне!
#
# Тебе практически удалось справиться с выпускным проектом, поздравляю! Данные из разных таблиц собраны в один датафрейм, удалены аномалии, заполнены пропуски, получены новые признаки, а ненужные признаки удалены. Рассмотрено несколько моделей и сделан перебор параметров. Могу отметить самостоятельность и аналитический подход в выполнении проекта, хорошую аналитическую часть!
#
# Положительные моменты:
#
# - грамотное и понятное оформление кода;
#
# - аналитический подход — при удалении признаков и формировании новых написано соответствующее обоснование;
#
# - проведен анализ данных и корреляции признаков;
#
# - рассмотрены несколько моделей для обучения, выполнен перебор гиперпараметров.
#
# Сейчас есть несколько замечаний:
#
# - поправить обработку пропусков и аномалий в признаке TotalCharges;
#
# - добавить графики в исследовательском анализе;
#
# - поправить random_state;
#
# - написать небольшой вывод по работе.
#
# На данном этапе проект практически завершен, я также отметил рекомендации. У нас еще есть время — я отправлю проект, чтобы ты могла ознакомиться с проверкой, внести исправления и возможно задать вопросы =)
#
# Также на будущее стоит иметь ввиду, что метрика ROC-AUC является не единственной, всегда нужно прислушиваться к требованиями бизнеса. Обычно одной метрикой не ограничиваются, смотрят также Precision, Recall, и выбирают те, которые наиболее подходят для конкретных задач.
#
# Еще нужно смотреть на важность признаков в модели, чтобы понимать, какие параметры влияют на отток.
#
# Проверка важности признаков по модели это только один из способов (корреляция в том числе). Используют также аналитические методы проверки гипотез.
#
# Если есть какие-то вопросы, или нужны пояснения по проекту — смело пиши! Я постараюсь тебе помочь 😊
#
# Жду твоего ответа!
#
# </font>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Каламкас, поздравляю с выполнением основной части проекта!
#
# Пожалуйста, сохрани наши с тобой комментарии, а отчет продолжай выполнять ниже, в этом файле Jupyter Notebook.
#
# В отчете не забудь указать все пункты по предобработке данных, параметрам модели, набору признаков для обучения — чтобы была возможность воспроизвести твою работу, изучив только отчет.
#
# Необходимо выделить следующие пункты:
#
# - список признаков, которые использовались для обучения;
#
# - указать итоговую модель и ее гиперпараметры — желательно в отдельной строке, чтобы не сливалась с остальным текстом;
#
# - отличия от исходного плана работ;
#
# - в отчете нужно указать трудности в работе (если не было, то так и написать) и ключевые этапы (если ключевых этапов не было, то написать, что все этапы важны);
#
# - размер тестовой выборки, параметр random_state.
#
# Я принимаю работу и буду ждать твой отчет на проверку!
#
# </div>

# %% [markdown]
# <b>Отчет по проделанной работе:</b>

# %% [markdown]
# Итак, мы загрузили и объединили исходные данные в 1 датасет в PySpark SQL. Изучили общую информацию о датасете, заметили пропуски в данных и некорректный тип данных в отдельных полях. <br> Определили целевой признак - EndDate приведенный к бинарному типу - новое поле Outflow. Заменили поле BeginDate на ActiveDays как разницу между датой старта и окончания контракта / датой выгрузки данных. Исходное поле удалили, чтобы избежать утечки данных в ходе моделирования. <br> Заполнили пропуски в полях из таблицы internet_new значением No, а также в поле MultipleLines - на значение not defined. Получившийся датасет состоит из 7034 строк и 21 поля. Далее мы заменили тип данных в поле TotalCharges на float. <br> Мы также изучили ОС числовых признаков. Сравнимли распределения TotalCharges и ActiveDays для активных и ушедших клиентов. <br> Далее проверили наличие корреляции между признаками с помощью коэф $\phi_K$. Проверили стат значимость получившихся коэф-тов корреляции. <br> Поделили датасет на обучающую и тренировочную выборки. С помощью column_transformer закодировали категориальные признаки методом OHE и масштабировали числовые признаки.
